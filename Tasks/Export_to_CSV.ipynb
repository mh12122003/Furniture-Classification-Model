# %% [markdown]
# # Export to CSV Notebook

# %%
import os
import zipfile
import pandas as pd

# %%
# Define the zip file path relative to the current directory
zip_file = "../Furniture_Data.zip"

# Define the extraction directory (one level above)
extraction_dir = ".."

# Construct the full path to the extracted directory
extracted_dir_path = os.path.join(extraction_dir, "Furniture_Data") 

# Check if the extracted directory exists
if not os.path.exists(extracted_dir_path):
    # If the directory doesn't exist, unzip the file
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extraction_dir)
    print(f"File unzipped successfully to {extracted_dir_path}.")
else:
    # If the directory exists, do nothing
    print(f"Directory {extracted_dir_path} already exists. Skipping extraction.")
# Out:
# File unzipped successfully to ..\Furniture_Data.

# %%
# Define the root directory where categorical furniture folders are located
base_dataset_dir = "../Furniture_Data"

# Function to get all furniture category names within a directory
def get_furniture_categories(directory):
    """
    Gets all directory names within a given directory.

    Args:
        directory (str): The path to the directory.

    Returns:
        list: A list of directory names within the given directory.
    """
    return [
        item 
        for item in os.listdir(directory) 
        if os.path.isdir(os.path.join(directory, item))
    ]

# Function to get the number of categorical furniture folders and the number of folders within each categorical folder
def get_category_info(root_dir):
    """
    Gets information about furniture categories and their subfolders.

    Args:
        root_dir (str): The path to the root directory containing furniture categories.

    Returns:
        tuple: A tuple containing:
            - int: The number of furniture categories.
            - dict: A dictionary where keys are category names and values are dictionaries containing
                   'num_folders' (number of subfolders) and 'folders' (list of subfolder names).
    """
    categorical_folders = get_furniture_categories(root_dir)
    folder_info = {}
    for cat_folder in categorical_folders:
        cat_folder_path = os.path.join(root_dir, cat_folder)
        folders_in_cat = get_furniture_categories(cat_folder_path)
        folder_info[cat_folder] = {
            "num_folders": len(folders_in_cat),
            "folders": folders_in_cat
        }
    return len(categorical_folders), folder_info

# %%
# Get the number of categorical folders and the number of folders within each categorical folder
num_classes, folder_info = get_category_info(base_dataset_dir)

print(f"Number of furniture categories: {num_classes}")
print("Information for each category:")

for category, info in folder_info.items():
    print(f"- {category}:")
    print(f"  Number of subfolders: {info['num_folders']}")
    print(f"  Subfolders: {', '.join(info['folders'])}")
# Out:
# Number of furniture categories: 6
# Information for each category:
# - beds:
#   Number of subfolders: 17
#   Subfolders: Asian, Beach, Contemporary, Craftsman, Eclectic, Farmhouse, Industrial, Mediterranean, Midcentury, Modern, Rustic, Scandinavian, Southwestern, Traditional, Transitional, Tropical, Victorian
# - chairs:
#   Number of subfolders: 17
#   Subfolders: Asian, Beach, Contemporary, Craftsman, Eclectic, Farmhouse, Industrial, Mediterranean, Midcentury, Modern, Rustic, Scandinavian, Southwestern, Traditional, Transitional, Tropical, Victorian
# - dressers:
#   Number of subfolders: 17
#   Subfolders: Asian, Beach, Contemporary, Craftsman, Eclectic, Farmhouse, Industrial, Mediterranean, Midcentury, Modern, Rustic, Scandinavian, Southwestern, Traditional, Transitional, Tropical, Victorian
# - lamps:
#   Number of subfolders: 17
#   Subfolders: Asian, Beach, Contemporary, Craftsman, Eclectic, Farmhouse, Industrial, Mediterranean, Midcentury, Modern, Rustic, Scandinavian, Southwestern, Traditional, Transitional, Tropical, Victorian
# - sofas:
#   Number of subfolders: 17
#   Subfolders: Asian, Beach, Contemporary, Craftsman, Eclectic, Farmhouse, Industrial, Mediterranean, Midcentury, Modern, Rustic, Scandinavian, Southwestern, Traditional, Transitional, Tropical, Victorian
# - tables:
#   Number of subfolders: 17
#   Subfolders: Asian, Beach, Contemporary, Craftsman, Eclectic, Farmhouse, Industrial, Mediterranean, Midcentury, Modern, Rustic, Scandinavian, Southwestern, Traditional, Transitional, Tropical, Victorian

# %%
def get_image_paths_dict(root_dir):
    """
    Creates a dictionary containing image paths organized by category and furniture type.

    Args:
        root_dir (str): The path to the root directory containing furniture categories.

    Returns:
        dict: A dictionary where keys are category names, and values are dictionaries. 
              Each nested dictionary has keys representing furniture types, and values are lists of image paths for that type.
    """
    image_paths_dict = {}
    for category, info in folder_info.items():
        image_paths_dict[category] = {
            furniture_type: [
                os.path.join(root_dir, category, furniture_type, img_path)
                for img_path in os.listdir(os.path.join(root_dir, category, furniture_type))
            ] 
            for furniture_type in info['folders']
        }
    return image_paths_dict

# Get the image paths as a dictionary
image_paths_dict = get_image_paths_dict(base_dataset_dir)

# Print example paths from the dictionary
for category, furniture_types in image_paths_dict.items():
    print(f"Category: {category}")
    for furniture_type, paths in furniture_types.items():
        print(f"  - Furniture type: {furniture_type}")
        print("    Example paths:")
        for path in paths[:3]:  
            print(f"      {path}")
        print("    ...")
# Out:
# Category: beds
#   - Furniture type: Asian
#     Example paths:
#       ../Furniture_Data\beds\Asian\19726asian-daybeds.jpg
#       ../Furniture_Data\beds\Asian\20027asian-canopy-beds.jpg
#       ../Furniture_Data\beds\Asian\20109asian-panel-beds.jpg
#     ...
#   - Furniture type: Beach
#     Example paths:
#       ../Furniture_Data\beds\Beach\24547beach-style-nightstands-and-bedside-tables.jpg
#       ../Furniture_Data\beds\Beach\2832beach-style-canopy-beds.jpg
#       ../Furniture_Data\beds\Beach\3858beach-style-panel-beds.jpg
#     ...
#   - Furniture type: Contemporary
#     Example paths:
#       ../Furniture_Data\beds\Contemporary\1001contemporary-platform-beds.jpg
#       ../Furniture_Data\beds\Contemporary\1002contemporary-bunk-beds.jpg
#       ../Furniture_Data\beds\Contemporary\1003contemporary-adjustable-beds.jpg
#     ...
#   - Furniture type: Craftsman
#     Example paths:
#       ../Furniture_Data\beds\Craftsman\2638craftsman-panel-beds.jpg
#       ../Furniture_Data\beds\Craftsman\2671craftsman-platform-beds.jpg
#       ../Furniture_Data\beds\Craftsman\27972craftsman-daybeds.jpg
#     ...
#   - Furniture type: Eclectic
#     Example paths:
#       ../Furniture_Data\beds\Eclectic\2677eclectic-kids-beds.jpg
#       ../Furniture_Data\beds\Eclectic\2715eclectic-kids-beds.jpg
#       ../Furniture_Data\beds\Eclectic\4380eclectic-panel-beds.jpg
#     ...
#   - Furniture type: Farmhouse
#     Example paths:
#       ../Furniture_Data\beds\Farmhouse\10350farmhouse-bunk-beds.jpg
#       ../Furniture_Data\beds\Farmhouse\2761farmhouse-canopy-beds.jpg
#       ../Furniture_Data\beds\Farmhouse\2912farmhouse-daybeds.jpg
#     ...
#   - Furniture type: Industrial
#     Example paths:
#       ../Furniture_Data\beds\Industrial\2515industrial-platform-beds.jpg
#       ../Furniture_Data\beds\Industrial\2554industrial-panel-beds.jpg
#       ../Furniture_Data\beds\Industrial\2645industrial-bunk-beds.jpg
#     ...
#   - Furniture type: Mediterranean
#     Example paths:
#       ../Furniture_Data\beds\Mediterranean\2634mediterranean-panel-beds.jpg
#       ../Furniture_Data\beds\Mediterranean\2833mediterranean-kids-beds.jpg
#       ../Furniture_Data\beds\Mediterranean\2856mediterranean-panel-beds.jpg
#     ...
#   - Furniture type: Midcentury
#     Example paths:
#       ../Furniture_Data\beds\Midcentury\2523midcentury-platform-beds.jpg
#       ../Furniture_Data\beds\Midcentury\2577midcentury-platform-beds.jpg
#       ../Furniture_Data\beds\Midcentury\2608midcentury-platform-beds.jpg
#     ...
#   - Furniture type: Modern
#     Example paths:
#       ../Furniture_Data\beds\Modern\2512modern-platform-beds.jpg
#       ../Furniture_Data\beds\Modern\2527modern-platform-beds.jpg
#       ../Furniture_Data\beds\Modern\2536modern-platform-beds.jpg
#     ...
#   - Furniture type: Rustic
#     Example paths:
#       ../Furniture_Data\beds\Rustic\2530rustic-platform-beds.jpg
#       ../Furniture_Data\beds\Rustic\2547rustic-kids-beds.jpg
#       ../Furniture_Data\beds\Rustic\2558rustic-platform-beds.jpg
#     ...
#   - Furniture type: Scandinavian
#     Example paths:
#       ../Furniture_Data\beds\Scandinavian\2627scandinavian-platform-beds.jpg
#       ../Furniture_Data\beds\Scandinavian\2628scandinavian-platform-beds.jpg
#       ../Furniture_Data\beds\Scandinavian\2654scandinavian-bunk-beds.jpg
#     ...
#   - Furniture type: Southwestern
#     Example paths:
#       ../Furniture_Data\beds\Southwestern\3052southwestern-loft-beds.jpg
#       ../Furniture_Data\beds\Southwestern\5141southwestern-loft-beds.jpg
#       ../Furniture_Data\beds\Southwestern\5537southwestern-panel-beds.jpg
#     ...
#   - Furniture type: Traditional
#     Example paths:
#       ../Furniture_Data\beds\Traditional\10353traditional-sleigh-beds.jpg
#       ../Furniture_Data\beds\Traditional\10507traditional-canopy-beds.jpg
#       ../Furniture_Data\beds\Traditional\10510traditional-panel-beds.jpg
#     ...
#   - Furniture type: Transitional
#     Example paths:
#       ../Furniture_Data\beds\Transitional\10000transitional-panel-beds.jpg
#       ../Furniture_Data\beds\Transitional\10001transitional-bunk-beds.jpg
#       ../Furniture_Data\beds\Transitional\10002transitional-platform-beds.jpg
#     ...
#   - Furniture type: Tropical
#     Example paths:
#       ../Furniture_Data\beds\Tropical\10368tropical-panel-beds.jpg
#       ../Furniture_Data\beds\Tropical\10406tropical-daybeds.jpg
#       ../Furniture_Data\beds\Tropical\10407tropical-panel-beds.jpg
#     ...
#   - Furniture type: Victorian
#     Example paths:
#       ../Furniture_Data\beds\Victorian\10443victorian-sleigh-beds.jpg
#       ../Furniture_Data\beds\Victorian\10444victorian-panel-beds.jpg
#       ../Furniture_Data\beds\Victorian\10445victorian-panel-beds.jpg
#     ...
# Category: chairs
#   - Furniture type: Asian
#     Example paths:
#       ../Furniture_Data\chairs\Asian\13989asian-dining-chairs.jpg
#       ../Furniture_Data\chairs\Asian\13990asian-folding-chairs-and-stools.jpg
#       ../Furniture_Data\chairs\Asian\13991asian-indoor-chaise-lounge-chairs.jpg
#     ...
#   - Furniture type: Beach
#     Example paths:
#       ../Furniture_Data\chairs\Beach\13947beach-style-dining-chairs.jpg
#       ../Furniture_Data\chairs\Beach\14273beach-style-dining-chairs.jpg
#       ../Furniture_Data\chairs\Beach\14371beach-style-dining-chairs.jpg
#     ...
#   - Furniture type: Contemporary
#     Example paths:
#       ../Furniture_Data\chairs\Contemporary\0contemporary-recliner-chairs.jpg
#       ../Furniture_Data\chairs\Contemporary\1000contemporary-indoor-chaise-lounge-chairs.jpg
#       ../Furniture_Data\chairs\Contemporary\1001contemporary-theater-seating.jpg
#     ...
#   - Furniture type: Craftsman
#     Example paths:
#       ../Furniture_Data\chairs\Craftsman\13964craftsman-gliders.jpg
#       ../Furniture_Data\chairs\Craftsman\14536craftsman-folding-chairs-and-stools.jpg
#       ../Furniture_Data\chairs\Craftsman\14537craftsman-rocking-chairs.jpg
#     ...
#   - Furniture type: Eclectic
#     Example paths:
#       ../Furniture_Data\chairs\Eclectic\4870eclectic-dining-chairs.jpg
#       ../Furniture_Data\chairs\Eclectic\4871eclectic-dining-chairs.jpg
#       ../Furniture_Data\chairs\Eclectic\4872eclectic-armchairs-and-accent-chairs.jpg
#     ...
#   - Furniture type: Farmhouse
#     Example paths:
#       ../Furniture_Data\chairs\Farmhouse\13891farmhouse-dining-chairs.jpg
#       ../Furniture_Data\chairs\Farmhouse\13898farmhouse-dining-chairs.jpg
#       ../Furniture_Data\chairs\Farmhouse\13904farmhouse-dining-chairs.jpg
#     ...
#   - Furniture type: Industrial
#     Example paths:
#       ../Furniture_Data\chairs\Industrial\13957industrial-armchairs-and-accent-chairs.jpg
#       ../Furniture_Data\chairs\Industrial\13981industrial-folding-chairs-and-stools.jpg
#       ../Furniture_Data\chairs\Industrial\14686industrial-dining-chairs.jpg
#     ...
#   - Furniture type: Mediterranean
#     Example paths:
#       ../Furniture_Data\chairs\Mediterranean\14250mediterranean-armchairs-and-accent-chairs.jpg
#       ../Furniture_Data\chairs\Mediterranean\14351mediterranean-dining-chairs.jpg
#       ../Furniture_Data\chairs\Mediterranean\16937mediterranean-armchairs-and-accent-chairs.jpg
#     ...
#   - Furniture type: Midcentury
#     Example paths:
#       ../Furniture_Data\chairs\Midcentury\1408midcentury-armchairs-and-accent-chairs.jpg
#       ../Furniture_Data\chairs\Midcentury\14214midcentury-armchairs-and-accent-chairs.jpg
#       ../Furniture_Data\chairs\Midcentury\14263midcentury-armchairs-and-accent-chairs.jpg
#     ...
#   - Furniture type: Modern
#     Example paths:
#       ../Furniture_Data\chairs\Modern\10245modern-dining-tables.jpg
#       ../Furniture_Data\chairs\Modern\10246modern-dining-tables.jpg
#       ../Furniture_Data\chairs\Modern\11294modern-vanity-stools-and-benches.jpg
#     ...
#   - Furniture type: Rustic
#     Example paths:
#       ../Furniture_Data\chairs\Rustic\13975rustic-dining-chairs.jpg
#       ../Furniture_Data\chairs\Rustic\13987rustic-indoor-chaise-lounge-chairs.jpg
#       ../Furniture_Data\chairs\Rustic\14673rustic-dining-chairs.jpg
#     ...
#   - Furniture type: Scandinavian
#     Example paths:
#       ../Furniture_Data\chairs\Scandinavian\14352scandinavian-dining-chairs.jpg
#       ../Furniture_Data\chairs\Scandinavian\14759scandinavian-armchairs-and-accent-chairs.jpg
#       ../Furniture_Data\chairs\Scandinavian\15869scandinavian-armchairs-and-accent-chairs.jpg
#     ...
#   - Furniture type: Southwestern
#     Example paths:
#       ../Furniture_Data\chairs\Southwestern\13895southwestern-armchairs-and-accent-chairs.jpg
#       ../Furniture_Data\chairs\Southwestern\15350southwestern-dining-chairs.jpg
#       ../Furniture_Data\chairs\Southwestern\16217southwestern-armchairs-and-accent-chairs.jpg
#     ...
#   - Furniture type: Traditional
#     Example paths:
#       ../Furniture_Data\chairs\Traditional\10002traditional-dining-chairs.jpg
#       ../Furniture_Data\chairs\Traditional\10003traditional-armchairs-and-accent-chairs.jpg
#       ../Furniture_Data\chairs\Traditional\10004traditional-dining-chairs.jpg
#     ...
#   - Furniture type: Transitional
#     Example paths:
#       ../Furniture_Data\chairs\Transitional\11286transitional-dining-chairs.jpg
#       ../Furniture_Data\chairs\Transitional\12864transitional-dining-chairs.jpg
#       ../Furniture_Data\chairs\Transitional\13535transitional-armchairs-and-accent-chairs.jpg
#     ...
#   - Furniture type: Tropical
#     Example paths:
#       ../Furniture_Data\chairs\Tropical\14165tropical-dining-chairs.jpg
#       ../Furniture_Data\chairs\Tropical\14215tropical-armchairs-and-accent-chairs.jpg
#       ../Furniture_Data\chairs\Tropical\14322tropical-dining-chairs.jpg
#     ...
#   - Furniture type: Victorian
#     Example paths:
#       ../Furniture_Data\chairs\Victorian\11957victorian-dining-chairs.jpg
#       ../Furniture_Data\chairs\Victorian\11958victorian-dining-chairs.jpg
#       ../Furniture_Data\chairs\Victorian\12612victorian-dining-chairs.jpg
#     ...
# Category: dressers
#   - Furniture type: Asian
#     Example paths:
#       ../Furniture_Data\dressers\Asian\1296asian-dressers.jpg
#       ../Furniture_Data\dressers\Asian\1337asian-dressers.jpg
#       ../Furniture_Data\dressers\Asian\1355asian-dressers.jpg
#     ...
#   - Furniture type: Beach
#     Example paths:
#       ../Furniture_Data\dressers\Beach\1369beach-style-dressers.jpg
#       ../Furniture_Data\dressers\Beach\1487beach-style-dressers.jpg
#       ../Furniture_Data\dressers\Beach\1533beach-style-dressers.jpg
#     ...
#   - Furniture type: Contemporary
#     Example paths:
#       ../Furniture_Data\dressers\Contemporary\0contemporary-dressers.jpg
#       ../Furniture_Data\dressers\Contemporary\1000contemporary-dressers.jpg
#       ../Furniture_Data\dressers\Contemporary\1001contemporary-dressers.jpg
#     ...
#   - Furniture type: Craftsman
#     Example paths:
#       ../Furniture_Data\dressers\Craftsman\1230craftsman-dressers.jpg
#       ../Furniture_Data\dressers\Craftsman\1374craftsman-dressers.jpg
#       ../Furniture_Data\dressers\Craftsman\1605craftsman-dressers.jpg
#     ...
#   - Furniture type: Eclectic
#     Example paths:
#       ../Furniture_Data\dressers\Eclectic\1253eclectic-dressers.jpg
#       ../Furniture_Data\dressers\Eclectic\1368eclectic-dressers.jpg
#       ../Furniture_Data\dressers\Eclectic\1965eclectic-dressers.jpg
#     ...
#   - Furniture type: Farmhouse
#     Example paths:
#       ../Furniture_Data\dressers\Farmhouse\1275farmhouse-dressers.jpg
#       ../Furniture_Data\dressers\Farmhouse\1312farmhouse-dressers.jpg
#       ../Furniture_Data\dressers\Farmhouse\1403farmhouse-dressers.jpg
#     ...
#   - Furniture type: Industrial
#     Example paths:
#       ../Furniture_Data\dressers\Industrial\1291industrial-dressers.jpg
#       ../Furniture_Data\dressers\Industrial\1294industrial-dressers.jpg
#       ../Furniture_Data\dressers\Industrial\1386industrial-dressers.jpg
#     ...
#   - Furniture type: Mediterranean
#     Example paths:
#       ../Furniture_Data\dressers\Mediterranean\1367mediterranean-dressers.jpg
#       ../Furniture_Data\dressers\Mediterranean\1877mediterranean-dressers.jpg
#       ../Furniture_Data\dressers\Mediterranean\2046mediterranean-dressers.jpg
#     ...
#   - Furniture type: Midcentury
#     Example paths:
#       ../Furniture_Data\dressers\Midcentury\1235midcentury-dressers.jpg
#       ../Furniture_Data\dressers\Midcentury\1236midcentury-dressers.jpg
#       ../Furniture_Data\dressers\Midcentury\1250midcentury-dressers.jpg
#     ...
#   - Furniture type: Modern
#     Example paths:
#       ../Furniture_Data\dressers\Modern\10048modern-side-tables-and-end-tables.jpg
#       ../Furniture_Data\dressers\Modern\10071modern-console-tables.jpg
#       ../Furniture_Data\dressers\Modern\10079modern-nightstands-and-bedside-tables.jpg
#     ...
#   - Furniture type: Rustic
#     Example paths:
#       ../Furniture_Data\dressers\Rustic\1242rustic-dressers.jpg
#       ../Furniture_Data\dressers\Rustic\1243rustic-dressers.jpg
#       ../Furniture_Data\dressers\Rustic\1276rustic-dressers.jpg
#     ...
#   - Furniture type: Scandinavian
#     Example paths:
#       ../Furniture_Data\dressers\Scandinavian\1329scandinavian-dressers.jpg
#       ../Furniture_Data\dressers\Scandinavian\1353scandinavian-dressers.jpg
#       ../Furniture_Data\dressers\Scandinavian\1547scandinavian-dressers.jpg
#     ...
#   - Furniture type: Southwestern
#     Example paths:
#       ../Furniture_Data\dressers\Southwestern\2590southwestern-dressers.jpg
#       ../Furniture_Data\dressers\Southwestern\28896southwestern-nightstands-and-bedside-tables.jpg
#       ../Furniture_Data\dressers\Southwestern\5367southwestern-dressers.jpg
#     ...
#   - Furniture type: Traditional
#     Example paths:
#       ../Furniture_Data\dressers\Traditional\1231traditional-dressers.jpg
#       ../Furniture_Data\dressers\Traditional\1232traditional-dressers.jpg
#       ../Furniture_Data\dressers\Traditional\1244traditional-dressers.jpg
#     ...
#   - Furniture type: Transitional
#     Example paths:
#       ../Furniture_Data\dressers\Transitional\1226transitional-dressers.jpg
#       ../Furniture_Data\dressers\Transitional\1229transitional-dressers.jpg
#       ../Furniture_Data\dressers\Transitional\1233transitional-dressers.jpg
#     ...
#   - Furniture type: Tropical
#     Example paths:
#       ../Furniture_Data\dressers\Tropical\1310tropical-dressers.jpg
#       ../Furniture_Data\dressers\Tropical\1373tropical-dressers.jpg
#       ../Furniture_Data\dressers\Tropical\1657tropical-dressers.jpg
#     ...
#   - Furniture type: Victorian
#     Example paths:
#       ../Furniture_Data\dressers\Victorian\1364victorian-dressers.jpg
#       ../Furniture_Data\dressers\Victorian\1645victorian-dressers.jpg
#       ../Furniture_Data\dressers\Victorian\1745victorian-dressers.jpg
#     ...
# Category: lamps
#   - Furniture type: Asian
#     Example paths:
#       ../Furniture_Data\lamps\Asian\13898asian-table-lamps.jpg
#       ../Furniture_Data\lamps\Asian\13899asian-table-lamps.jpg
#       ../Furniture_Data\lamps\Asian\13900asian-table-lamps.jpg
#     ...
#   - Furniture type: Beach
#     Example paths:
#       ../Furniture_Data\lamps\Beach\14734beach-style-table-lamps.jpg
#       ../Furniture_Data\lamps\Beach\14828beach-style-table-lamps.jpg
#       ../Furniture_Data\lamps\Beach\14877beach-style-table-lamps.jpg
#     ...
#   - Furniture type: Contemporary
#     Example paths:
#       ../Furniture_Data\lamps\Contemporary\0contemporary-floor-lamps.jpg
#       ../Furniture_Data\lamps\Contemporary\1000contemporary-table-lamps.jpg
#       ../Furniture_Data\lamps\Contemporary\1001contemporary-desk-lamps.jpg
#     ...
#   - Furniture type: Craftsman
#     Example paths:
#       ../Furniture_Data\lamps\Craftsman\14698craftsman-floor-lamps.jpg
#       ../Furniture_Data\lamps\Craftsman\14720craftsman-table-lamps.jpg
#       ../Furniture_Data\lamps\Craftsman\14731craftsman-floor-lamps.jpg
#     ...
#   - Furniture type: Eclectic
#     Example paths:
#       ../Furniture_Data\lamps\Eclectic\17365eclectic-table-lamps.jpg
#       ../Furniture_Data\lamps\Eclectic\17388eclectic-table-lamps.jpg
#       ../Furniture_Data\lamps\Eclectic\19148eclectic-table-lamps.jpg
#     ...
#   - Furniture type: Farmhouse
#     Example paths:
#       ../Furniture_Data\lamps\Farmhouse\10549farmhouse-table-lamps.jpg
#       ../Furniture_Data\lamps\Farmhouse\10556farmhouse-table-lamps.jpg
#       ../Furniture_Data\lamps\Farmhouse\14696farmhouse-table-lamps.jpg
#     ...
#   - Furniture type: Industrial
#     Example paths:
#       ../Furniture_Data\lamps\Industrial\14773industrial-table-lamps.jpg
#       ../Furniture_Data\lamps\Industrial\14804industrial-table-lamps.jpg
#       ../Furniture_Data\lamps\Industrial\17334industrial-floor-lamps.jpg
#     ...
#   - Furniture type: Mediterranean
#     Example paths:
#       ../Furniture_Data\lamps\Mediterranean\14700mediterranean-table-lamps.jpg
#       ../Furniture_Data\lamps\Mediterranean\14770mediterranean-table-lamps.jpg
#       ../Furniture_Data\lamps\Mediterranean\14774mediterranean-table-lamps.jpg
#     ...
#   - Furniture type: Midcentury
#     Example paths:
#       ../Furniture_Data\lamps\Midcentury\14777midcentury-floor-lamps.jpg
#       ../Furniture_Data\lamps\Midcentury\14932midcentury-table-lamps.jpg
#       ../Furniture_Data\lamps\Midcentury\17440midcentury-table-lamps.jpg
#     ...
#   - Furniture type: Modern
#     Example paths:
#       ../Furniture_Data\lamps\Modern\10074modern-table-lamps.jpg
#       ../Furniture_Data\lamps\Modern\10075modern-table-lamps.jpg
#       ../Furniture_Data\lamps\Modern\10141modern-table-lamps.jpg
#     ...
#   - Furniture type: Rustic
#     Example paths:
#       ../Furniture_Data\lamps\Rustic\14701rustic-table-lamps.jpg
#       ../Furniture_Data\lamps\Rustic\14754rustic-table-lamps.jpg
#       ../Furniture_Data\lamps\Rustic\14791rustic-table-lamps.jpg
#     ...
#   - Furniture type: Scandinavian
#     Example paths:
#       ../Furniture_Data\lamps\Scandinavian\16548scandinavian-table-lamps.jpg
#       ../Furniture_Data\lamps\Scandinavian\19333scandinavian-table-lamps.jpg
#       ../Furniture_Data\lamps\Scandinavian\20873scandinavian-floor-lamps.jpg
#     ...
#   - Furniture type: Southwestern
#     Example paths:
#       ../Furniture_Data\lamps\Southwestern\14699southwestern-floor-lamps.jpg
#       ../Furniture_Data\lamps\Southwestern\14933southwestern-table-lamps.jpg
#       ../Furniture_Data\lamps\Southwestern\17362southwestern-floor-lamps.jpg
#     ...
#   - Furniture type: Traditional
#     Example paths:
#       ../Furniture_Data\lamps\Traditional\10000traditional-table-lamps.jpg
#       ../Furniture_Data\lamps\Traditional\10003traditional-table-lamps.jpg
#       ../Furniture_Data\lamps\Traditional\10004traditional-table-lamps.jpg
#     ...
#   - Furniture type: Transitional
#     Example paths:
#       ../Furniture_Data\lamps\Transitional\10396transitional-desk-lamps.jpg
#       ../Furniture_Data\lamps\Transitional\12344transitional-table-lamps.jpg
#       ../Furniture_Data\lamps\Transitional\14695transitional-floor-lamps.jpg
#     ...
#   - Furniture type: Tropical
#     Example paths:
#       ../Furniture_Data\lamps\Tropical\14710tropical-table-lamps.jpg
#       ../Furniture_Data\lamps\Tropical\14715tropical-table-lamps.jpg
#       ../Furniture_Data\lamps\Tropical\14722tropical-table-lamps.jpg
#     ...
#   - Furniture type: Victorian
#     Example paths:
#       ../Furniture_Data\lamps\Victorian\14706victorian-table-lamps.jpg
#       ../Furniture_Data\lamps\Victorian\14716victorian-table-lamps.jpg
#       ../Furniture_Data\lamps\Victorian\14729victorian-floor-lamps.jpg
#     ...
# Category: sofas
#   - Furniture type: Asian
#     Example paths:
#       ../Furniture_Data\sofas\Asian\3634asian-sofas.jpg
#       ../Furniture_Data\sofas\Asian\3635asian-sofas.jpg
#       ../Furniture_Data\sofas\Asian\3636asian-sofas.jpg
#     ...
#   - Furniture type: Beach
#     Example paths:
#       ../Furniture_Data\sofas\Beach\2534beach-style-sofas.jpg
#       ../Furniture_Data\sofas\Beach\25759beach-style-outdoor-sofas.jpg
#       ../Furniture_Data\sofas\Beach\25962beach-style-outdoor-sofas.jpg
#     ...
#   - Furniture type: Contemporary
#     Example paths:
#       ../Furniture_Data\sofas\Contemporary\0contemporary-sofas.jpg
#       ../Furniture_Data\sofas\Contemporary\1000contemporary-sofas.jpg
#       ../Furniture_Data\sofas\Contemporary\1002contemporary-sofas.jpg
#     ...
#   - Furniture type: Craftsman
#     Example paths:
#       ../Furniture_Data\sofas\Craftsman\1641craftsman-sofas.jpg
#       ../Furniture_Data\sofas\Craftsman\2192craftsman-outdoor-lounge-sets.jpg
#       ../Furniture_Data\sofas\Craftsman\27215craftsman-outdoor-lounge-sets.jpg
#     ...
#   - Furniture type: Eclectic
#     Example paths:
#       ../Furniture_Data\sofas\Eclectic\1916eclectic-sofas.jpg
#       ../Furniture_Data\sofas\Eclectic\1917eclectic-sofas.jpg
#       ../Furniture_Data\sofas\Eclectic\1918eclectic-sofas.jpg
#     ...
#   - Furniture type: Farmhouse
#     Example paths:
#       ../Furniture_Data\sofas\Farmhouse\1888farmhouse-sofas.jpg
#       ../Furniture_Data\sofas\Farmhouse\1957farmhouse-sofas.jpg
#       ../Furniture_Data\sofas\Farmhouse\2937farmhouse-sofas.jpg
#     ...
#   - Furniture type: Industrial
#     Example paths:
#       ../Furniture_Data\sofas\Industrial\1574industrial-sofas.jpg
#       ../Furniture_Data\sofas\Industrial\1579industrial-sofas.jpg
#       ../Furniture_Data\sofas\Industrial\2481industrial-sofas.jpg
#     ...
#   - Furniture type: Mediterranean
#     Example paths:
#       ../Furniture_Data\sofas\Mediterranean\1423mediterranean-sofas.jpg
#       ../Furniture_Data\sofas\Mediterranean\2402mediterranean-sofas.jpg
#       ../Furniture_Data\sofas\Mediterranean\2705mediterranean-sofas.jpg
#     ...
#   - Furniture type: Midcentury
#     Example paths:
#       ../Furniture_Data\sofas\Midcentury\10256midcentury-loveseats.jpg
#       ../Furniture_Data\sofas\Midcentury\10264midcentury-loveseats.jpg
#       ../Furniture_Data\sofas\Midcentury\1364midcentury-sofas.jpg
#     ...
#   - Furniture type: Modern
#     Example paths:
#       ../Furniture_Data\sofas\Modern\13281modern-outdoor-sofas.jpg
#       ../Furniture_Data\sofas\Modern\1363modern-sofas.jpg
#       ../Furniture_Data\sofas\Modern\1366modern-sofas.jpg
#     ...
#   - Furniture type: Rustic
#     Example paths:
#       ../Furniture_Data\sofas\Rustic\1447rustic-sofas.jpg
#       ../Furniture_Data\sofas\Rustic\2370rustic-sofas.jpg
#       ../Furniture_Data\sofas\Rustic\4146rustic-sofas.jpg
#     ...
#   - Furniture type: Scandinavian
#     Example paths:
#       ../Furniture_Data\sofas\Scandinavian\1549scandinavian-sofas.jpg
#       ../Furniture_Data\sofas\Scandinavian\2235scandinavian-sofas.jpg
#       ../Furniture_Data\sofas\Scandinavian\2236scandinavian-sofas.jpg
#     ...
#   - Furniture type: Southwestern
#     Example paths:
#       ../Furniture_Data\sofas\Southwestern\1609southwestern-sofas.jpg
#       ../Furniture_Data\sofas\Southwestern\1778southwestern-sofas.jpg
#       ../Furniture_Data\sofas\Southwestern\17southwestern-sofas.jpg
#     ...
#   - Furniture type: Traditional
#     Example paths:
#       ../Furniture_Data\sofas\Traditional\1361traditional-sofas.jpg
#       ../Furniture_Data\sofas\Traditional\1365traditional-sofas.jpg
#       ../Furniture_Data\sofas\Traditional\1368traditional-sofas.jpg
#     ...
#   - Furniture type: Transitional
#     Example paths:
#       ../Furniture_Data\sofas\Transitional\1360transitional-sofas.jpg
#       ../Furniture_Data\sofas\Transitional\1367transitional-sofas.jpg
#       ../Furniture_Data\sofas\Transitional\1370transitional-sofas.jpg
#     ...
#   - Furniture type: Tropical
#     Example paths:
#       ../Furniture_Data\sofas\Tropical\2292tropical-sofas.jpg
#       ../Furniture_Data\sofas\Tropical\2302tropical-sofas.jpg
#       ../Furniture_Data\sofas\Tropical\2369tropical-sofas.jpg
#     ...
#   - Furniture type: Victorian
#     Example paths:
#       ../Furniture_Data\sofas\Victorian\1385victorian-sofas.jpg
#       ../Furniture_Data\sofas\Victorian\1388victorian-sofas.jpg
#       ../Furniture_Data\sofas\Victorian\2150victorian-sofas.jpg
#     ...
# Category: tables
#   - Furniture type: Asian
#     Example paths:
#       ../Furniture_Data\tables\Asian\1.jpg
#       ../Furniture_Data\tables\Asian\17599asian-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Asian\17600asian-side-tables-and-end-tables.jpg
#     ...
#   - Furniture type: Beach
#     Example paths:
#       ../Furniture_Data\tables\Beach\131.jpg
#       ../Furniture_Data\tables\Beach\132.jpg
#       ../Furniture_Data\tables\Beach\22372beach-style-side-tables-and-end-tables.jpg
#     ...
#   - Furniture type: Contemporary
#     Example paths:
#       ../Furniture_Data\tables\Contemporary\0contemporary-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Contemporary\1000contemporary-dining-tables.jpg
#       ../Furniture_Data\tables\Contemporary\1001contemporary-side-tables-and-end-tables.jpg
#     ...
#   - Furniture type: Craftsman
#     Example paths:
#       ../Furniture_Data\tables\Craftsman\122.jpg
#       ../Furniture_Data\tables\Craftsman\21101craftsman-console-tables.jpg
#       ../Furniture_Data\tables\Craftsman\21175craftsman-console-tables.jpg
#     ...
#   - Furniture type: Eclectic
#     Example paths:
#       ../Furniture_Data\tables\Eclectic\121.jpg
#       ../Furniture_Data\tables\Eclectic\1706eclectic-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Eclectic\3769eclectic-side-tables-and-end-tables.jpg
#     ...
#   - Furniture type: Farmhouse
#     Example paths:
#       ../Furniture_Data\tables\Farmhouse\123.jpg
#       ../Furniture_Data\tables\Farmhouse\124.jpg
#       ../Furniture_Data\tables\Farmhouse\126.jpg
#     ...
#   - Furniture type: Industrial
#     Example paths:
#       ../Furniture_Data\tables\Industrial\21097industrial-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Industrial\21112industrial-coffee-tables.jpg
#       ../Furniture_Data\tables\Industrial\21136industrial-coffee-tables.jpg
#     ...
#   - Furniture type: Mediterranean
#     Example paths:
#       ../Furniture_Data\tables\Mediterranean\21102mediterranean-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Mediterranean\21134mediterranean-plant-stands-and-telephone-tables.jpg
#       ../Furniture_Data\tables\Mediterranean\21151mediterranean-side-tables-and-end-tables.jpg
#     ...
#   - Furniture type: Midcentury
#     Example paths:
#       ../Furniture_Data\tables\Midcentury\129.jpg
#       ../Furniture_Data\tables\Midcentury\130.jpg
#       ../Furniture_Data\tables\Midcentury\140.jpg
#     ...
#   - Furniture type: Modern
#     Example paths:
#       ../Furniture_Data\tables\Modern\10.jpg
#       ../Furniture_Data\tables\Modern\100.jpg
#       ../Furniture_Data\tables\Modern\10000modern-dining-tables.jpg
#     ...
#   - Furniture type: Rustic
#     Example paths:
#       ../Furniture_Data\tables\Rustic\120.jpg
#       ../Furniture_Data\tables\Rustic\1227rustic-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Rustic\1639rustic-side-tables-and-end-tables.jpg
#     ...
#   - Furniture type: Scandinavian
#     Example paths:
#       ../Furniture_Data\tables\Scandinavian\0scandinavian-coffee-tables.jpg
#       ../Furniture_Data\tables\Scandinavian\10scandinavian-dining-tables.jpg
#       ../Furniture_Data\tables\Scandinavian\11scandinavian-dining-tables.jpg
#     ...
#   - Furniture type: Southwestern
#     Example paths:
#       ../Furniture_Data\tables\Southwestern\0southwestern-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Southwestern\10southwestern-coffee-tables.jpg
#       ../Furniture_Data\tables\Southwestern\11southwestern-table-tops-and-bases.jpg
#     ...
#   - Furniture type: Traditional
#     Example paths:
#       ../Furniture_Data\tables\Traditional\13454traditional-dining-tables.jpg
#       ../Furniture_Data\tables\Traditional\13455traditional-dining-tables.jpg
#       ../Furniture_Data\tables\Traditional\13457traditional-dining-tables.jpg
#     ...
#   - Furniture type: Transitional
#     Example paths:
#       ../Furniture_Data\tables\Transitional\14598transitional-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Transitional\14735transitional-outdoor-side-tables.jpg
#       ../Furniture_Data\tables\Transitional\21105transitional-dining-tables.jpg
#     ...
#   - Furniture type: Tropical
#     Example paths:
#       ../Furniture_Data\tables\Tropical\12432tropical-outdoor-side-tables.jpg
#       ../Furniture_Data\tables\Tropical\15530tropical-coffee-tables.jpg
#       ../Furniture_Data\tables\Tropical\21126tropical-side-tables-and-end-tables.jpg
#     ...
#   - Furniture type: Victorian
#     Example paths:
#       ../Furniture_Data\tables\Victorian\0victorian-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Victorian\10victorian-side-tables-and-end-tables.jpg
#       ../Furniture_Data\tables\Victorian\11victorian-side-tables-and-end-tables.jpg
#     ...

# %%
# Convert the dictionary of image paths directly into a DataFrame
furniture_df = pd.DataFrame([
    {"Furniture_Category": category, "Furniture_Type": furniture_type, "Image_Path": path}
    for category, furniture_types in image_paths_dict.items()
    for furniture_type, paths in furniture_types.items() 
    for path in paths 
])

# Print the DataFrame
print(furniture_df.head(10))
# Out:
#   Furniture_Category Furniture_Type  \
# 0               beds          Asian
# 1               beds          Asian
# 2               beds          Asian
# 3               beds          Asian
# 4               beds          Asian
# 5               beds          Asian
# 6               beds          Asian
# 7               beds          Asian
# 8               beds          Asian
# 9               beds          Asian
#
#                                           Image_Path
# 0  ../Furniture_Data\beds\Asian\19726asian-daybed...
# 1  ../Furniture_Data\beds\Asian\20027asian-canopy...
# 2  ../Furniture_Data\beds\Asian\20109asian-panel-...
# 3  ../Furniture_Data\beds\Asian\20508asian-platfo...
# 4  ../Furniture_Data\beds\Asian\20750asian-comfor...
# 5  ../Furniture_Data\beds\Asian\20802asian-platfo...
# 6  ../Furniture_Data\beds\Asian\2537asian-platfor...
# 7  ../Furniture_Data\beds\Asian\2637asian-platfor...
# 8  ../Furniture_Data\beds\Asian\2709asian-platfor...
# 9  ../Furniture_Data\beds\Asian\2730asian-platfor...

# %%
# Define the output CSV file path
output_csv = "../furniture_data.csv" 

# Save the DataFrame to a CSV file
furniture_df.to_csv(output_csv, index=False)

print(f"Furniture data saved to: {output_csv}")
# Out:
# Furniture data saved to: ../furniture_data.csv

# %% [markdown]
# # The end of Notebook
